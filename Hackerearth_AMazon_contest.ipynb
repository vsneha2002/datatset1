# %% [markdown]
# <a href="https://colab.research.google.com/github/vsneha2002/datatset1/blob/main/Hackerearth_AMazon_contest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as npn
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('dataset_final.csv')
df1=pd.read_csv('test_dataset_final.csv')

# %%
df.head()
# Out:
#      ID\t Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                 37.0                      4.9
# 1  0xb379     BANGRES18DEL02                 34.0                      4.5
# 2  0x5d6d     BANGRES19DEL01                 23.0                      4.4
# 3  0x7a6a    COIMBRES13DEL02                 38.0                      4.7
# 4  0x70a2     CHENRES12DEL01                 32.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID	                          45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          43739 non-null  float64
#  3   Delivery_person_Ratings      43685 non-null  float64
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  43862 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weather conditions           44977 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# ID\t                              0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# Name                              0
# dtype: int64

# %%
df.nunique()
# Out:
# ID\t                           45593
# Delivery_person_ID              1320
# Delivery_person_Age               22
# Delivery_person_Ratings           28
# Restaurant_latitude              657
# Restaurant_longitude             518
# Delivery_location_latitude      4373
# Delivery_location_longitude     4373
# Order_Date                        44
# Time_Orderd                      176
# Time_Order_picked                193
# Weather conditions                 6
# Road_traffic_density               4
# Vehicle_condition                  4
# Type_of_order                      4
# Type_of_vehicle                    4
# multiple_deliveries                4
# Festival                           2
# City                               3
# Time_taken (min)                  45
# Name                               1
# dtype: int64

# %%
df['Delivery_person_Age'].unique()
# Out:
# array([37., 34., 23., 38., 32., 22., 33., 35., 36., 21., 24., 29., 25.,
#        31., 27., 26., 20., nan, 28., 39., 30., 15., 50.])

# %%
a=df['Delivery_person_Age'].median()

# %%
a
# Out:
# 30.0

# %%
df['Delivery_person_Age']=df["Delivery_person_Age"].fillna(30.0)

# %%
df['Delivery_person_Age']
# Out:
# 0        37.0
# 1        34.0
# 2        23.0
# 3        38.0
# 4        32.0
#          ...
# 45588    30.0
# 45589    21.0
# 45590    30.0
# 45591    20.0
# 45592    23.0
# Name: Delivery_person_Age, Length: 45593, dtype: float64

# %%
df['Age'] = pd.cut(x=df['Delivery_person_Age'], bins=[10,20, 29, 39, 49,59], labels=['10s','20s', '30s', '40s','50s'])

# %%
df["Age"]
# Out:
# 0        30s
# 1        30s
# 2        20s
# 3        30s
# 4        30s
#         ...
# 45588    30s
# 45589    20s
# 45590    30s
# 45591    10s
# 45592    20s
# Name: Age, Length: 45593, dtype: category
# Categories (5, object): ['10s' < '20s' < '30s' < '40s' < '50s']

# %%
df['Delivery_person_Age'].unique()
# Out:
# array([37., 34., 23., 38., 32., 22., 33., 35., 36., 21., 24., 29., 25.,
#        31., 27., 26., 20., 30., 28., 39., 15., 50.])

# %%
df.isnull().sum()
# Out:
# ID\t                              0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# Name                              0
# Age                               0
# dtype: int64

# %%
df['Weather conditions'].unique()
# Out:
# array(['Sunny', 'Stormy', 'Sandstorms', 'Cloudy', 'Fog', 'Windy', nan],
#       dtype=object)

# %%
b=df['Weather conditions'].mode()

# %%
df['Weather conditions']=df["Weather conditions"].fillna('Fog')

# %%
df.isnull().sum()
# Out:
# ID\t                              0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather conditions                0
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# Name                              0
# Age                               0
# dtype: int64

# %%
df['City'].unique()
# Out:
# array(['Urban', 'Metropolitian', 'Semi-Urban', nan], dtype=object)

# %%
df['City'].mode()
# Out:
# 0    Metropolitian
# Name: City, dtype: object

# %%
df['City']=df["City"].fillna('Metropolitian')

# %%
df['Festival'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df['Festival'].mode()
# Out:
# 0    No
# Name: Festival, dtype: object

# %%
df['Festival']=df["Festival"].fillna('No')

# %%
df['multiple_deliveries'].unique()
# Out:
# array([ 0.,  1.,  3., nan,  2.])

# %%
df['multiple_deliveries'].median()
# Out:
# 1.0

# %%
df['multiple_deliveries']=df['multiple_deliveries'].fillna(1.0)

# %%
df['Road_traffic_density'].unique()
# Out:
# array(['High', 'Jam', 'Low', 'Medium', nan], dtype=object)

# %%
df['Road_traffic_density'].mode()
# Out:
# 0    Low
# Name: Road_traffic_density, dtype: object

# %%
df['Road_traffic_density']=df['Road_traffic_density'].fillna('Low')

# %%
df1.isnull().sum()
# Out:
# ID\t                             0
# Delivery_person_ID               0
# Delivery_person_Age            491
# Delivery_person_Ratings        507
# Restaurant_latitude              0
# Restaurant_longitude             0
# Delivery_location_latitude       0
# Delivery_location_longitude      0
# Order_Date                       0
# Time_Orderd                    444
# Time_Order_picked                0
# Weather conditions             158
# Road_traffic_density           154
# Vehicle_condition                0
# Type_of_order                    0
# Type_of_vehicle                  0
# multiple_deliveries            238
# Festival                        65
# City                           324
# Name                             0
# dtype: int64

# %%
from datetime import datetime

# %%
df['Time_Orderd'] = df['Time_Orderd'].values.astype(datetime)

# %%
print(df['Time_Orderd'].mode())
# Out:
# 0    21:55
# Name: Time_Orderd, dtype: object

# %%
df['Time_Orderd']=df['Time_Orderd'].fillna("21:55")

# %%
print(df1['Time_Orderd'].mode())
# Out:
# 0    18:20
# Name: Time_Orderd, dtype: object

# %%
df1['Time_Orderd']=df['Time_Orderd'].fillna("21:55")

# %%
df1['Road_traffic_density'].mode()
# Out:
# 0    Low
# Name: Road_traffic_density, dtype: object

# %%
df1['Road_traffic_density']=df1['Road_traffic_density'].fillna('Low')

# %%
df1['multiple_deliveries'].median()
# Out:
# 1.0

# %%
df1['multiple_deliveries']=df1['multiple_deliveries'].fillna(1.0)

# %%
df1['Festival'].mode()
# Out:
# 0    No
# Name: Festival, dtype: object

# %%
df1['Festival']=df1["Festival"].fillna('No')

# %%
df1['City'].mode()
# Out:
# 0    Metropolitian
# Name: City, dtype: object

# %%
df1['City']=df1["City"].fillna('Metropolitian')

# %%
df1['Weather conditions'].mode()
# Out:
# 0    Sunny
# Name: Weather conditions, dtype: object

# %%
df1['Weather conditions']=df1["Weather conditions"].fillna('Sunny')

# %%
x=df1['Delivery_person_Age'].median()

# %%
x
# Out:
# 30.0

# %%
df1['Delivery_person_Age']=df1["Delivery_person_Age"].fillna(30.0)

# %%
df1['Age'] = pd.cut(x=df['Delivery_person_Age'], bins=[10,20, 29, 39, 49,59], labels=['10s','20s', '30s', '40s','50s'])

# %%
df1.isnull().sum()
# Out:
# ID\t                             0
# Delivery_person_ID               0
# Delivery_person_Age              0
# Delivery_person_Ratings        507
# Restaurant_latitude              0
# Restaurant_longitude             0
# Delivery_location_latitude       0
# Delivery_location_longitude      0
# Order_Date                       0
# Time_Orderd                      0
# Time_Order_picked                0
# Weather conditions               0
# Road_traffic_density             0
# Vehicle_condition                0
# Type_of_order                    0
# Type_of_vehicle                  0
# multiple_deliveries              0
# Festival                         0
# City                             0
# Name                             0
# Age                              0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# ID\t                              0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                       0
# Time_Order_picked                 0
# Weather conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                          0
# City                              0
# Time_taken (min)                  0
# Name                              0
# Age                               0
# dtype: int64

# %%
df['Delivery_person_Ratings'].mode()
# Out:
# 0    4.8
# Name: Delivery_person_Ratings, dtype: float64

# %%
df['Delivery_person_Ratings']=df["Delivery_person_Ratings"].fillna(4.8)

# %%
df1['Delivery_person_Ratings'].mode()
# Out:
# 0    4.9
# Name: Delivery_person_Ratings, dtype: float64

# %%
df1['Delivery_person_Ratings']=df1["Delivery_person_Ratings"].fillna(4.9)

# %%
df.isnull().sum()
# Out:
# ID\t                           0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weather conditions             0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken (min)               0
# Name                           0
# Age                            0
# dtype: int64

# %%
df.head()
# Out:
#      ID\t Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                 37.0                      4.9
# 1  0xb379     BANGRES18DEL02                 34.0                      4.5
# 2  0x5d6d     BANGRES19DEL01                 23.0                      4.4
# 3  0x7a6a    COIMBRES13DEL02                 38.0                      4.7
# 4  0x70a2     CHENRES12DEL01                 32.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

# %%
df.Road_traffic_density=le.fit_transform(df.Road_traffic_density)
df1.Road_traffic_density=le.fit_transform(df1.Road_traffic_density)

# %%
df.Type_of_order=le.fit_transform(df.Type_of_order)
df1.Type_of_order=le.fit_transform(df1.Type_of_order)

# %%
df.Type_of_vehicle=le.fit_transform(df.Type_of_vehicle)
df1.Type_of_vehicle=le.fit_transform(df1.Type_of_vehicle)

# %%
df.Festival=le.fit_transform(df.Festival)
df1.Festival=le.fit_transform(df1.Festival)

# %%
df.City=le.fit_transform(df.City)
df1.City=le.fit_transform(df1.City)

# %%
df.Age=le.fit_transform(df.Age)
df1.Age=le.fit_transform(df1.Age)

# %%
df['Weather conditions']=le.fit_transform(df['Weather conditions'])
df1['Weather conditions']=le.fit_transform(df1['Weather conditions'])

# %%
df.head()
# Out:
#      ID\t Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                 37.0                      4.9
# 1  0xb379     BANGRES18DEL02                 34.0                      4.5
# 2  0x5d6d     BANGRES19DEL01                 23.0                      4.4
# 3  0x7a6a    COIMBRES13DEL02                 38.0                      4.7
# 4  0x70a2     CHENRES12DEL01                 32.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...  \
# ...

# %%
df1.head()
# Out:
#      ID\t Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x2318    COIMBRES13DEL01                 30.0                      4.9
# 1  0x3474     BANGRES15DEL01                 28.0                      4.6
# 2  0x9420      JAPRES09DEL03                 23.0                      4.5
# 3  0x72ee      JAPRES07DEL03                 21.0                      4.8
# 4  0xa759     CHENRES19DEL01                 31.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            11.003669             76.976494                   11.043669
# 1            12.975377             77.696664                   13.085377
# 2            26.911378             75.789034                   27.001378
# 3            26.766536             75.837333                   26.856536
# 4            12.986047             80.218114                   13.096047
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...  \
# ...

# %%
train=df.drop(['Name'],axis=1)
test=df1.drop(['Name'],axis=1)

# %%
df.head()
# Out:
#      ID\t Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                 37.0                      4.9
# 1  0xb379     BANGRES18DEL02                 34.0                      4.5
# 2  0x5d6d     BANGRES19DEL01                 23.0                      4.4
# 3  0x7a6a    COIMBRES13DEL02                 38.0                      4.7
# 4  0x70a2     CHENRES12DEL01                 32.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...  \
# ...

# %%
train.head()
# Out:
#      ID\t Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                 37.0                      4.9
# 1  0xb379     BANGRES18DEL02                 34.0                      4.5
# 2  0x5d6d     BANGRES19DEL01                 23.0                      4.4
# 3  0x7a6a    COIMBRES13DEL02                 38.0                      4.7
# 4  0x70a2     CHENRES12DEL01                 32.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...  \
# ...

# %%
test.head()
# Out:
#      ID\t Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x2318    COIMBRES13DEL01                 30.0                      4.9
# 1  0x3474     BANGRES15DEL01                 28.0                      4.6
# 2  0x9420      JAPRES09DEL03                 23.0                      4.5
# 3  0x72ee      JAPRES07DEL03                 21.0                      4.8
# 4  0xa759     CHENRES19DEL01                 31.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            11.003669             76.976494                   11.043669
# 1            12.975377             77.696664                   13.085377
# 2            26.911378             75.789034                   27.001378
# 3            26.766536             75.837333                   26.856536
# 4            12.986047             80.218114                   13.096047
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
import numpy as np
from math import radians, cos, sin, asin, sqrt

# %%
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance in kilometers between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles. Determines return value units.
    return c * r

# %%
distances_km = []
for row in train.itertuples(index=False):
   distances_km.append(haversine(row.Restaurant_latitude,row.Restaurant_longitude, row.Delivery_location_latitude, row.Delivery_location_longitude))

# %%
distances_km
# Out:
# [2.2889176429442766,
#  14.777224879337778,
#  1.1369661517622613,
#  5.698648755247188,
#  4.510870688286172,
#  3.402355554612758,
#  12.270796950704177,
#  14.834471478540268,
#  14.74215153593388,
#  7.947909355993949,
#  4.570359405666854,
#  10.382461955769202,
#  2.289660080808692,
#  14.653418262683628,
#  10.43205889546797,
#  4.564400471176787,
#  12.696968161012697,
#  7.938326774681736,
#  3.337200464424711,
#  9.22911227091784,
#  14.501942430996296,
#  1.1398128976994113,
#  14.659777692666824,
#  4.636457817153074,
#  12.403637848111313,
#  3.4345415625124036,
#  10.435138839387958,
#  10.233497755572916,
#  12.693406239781474,
#  3.419075289419169,
#  5.797754195048091,
#  5.771854217941541,
#  4.618264869797013,
#  17.29786575291325,
#  14.995683105740776,
#  8.079495962621806,
#  4.617534762216765,
#  1.159558704016293,
#  2.268442578384351,
#  2.2744494688005146,
#  7.959876989279569,
#  7.893990175172835,
#  9.270148568590898,
#  10.435081161445238,
# ...

# %%
distances_km1 = []
for row in test.itertuples(index=False):
   distances_km1.append(haversine(row.Restaurant_latitude,row.Restaurant_longitude, row.Delivery_location_latitude, row.Delivery_location_longitude))

# %%
distances_km1
# Out:
# [4.559002157269455,
#  12.503659429268597,
#  10.302876000359147,
#  10.300934436652051,
#  12.40477981738383,
#  1.154677612551188,
#  2.273892730894037,
#  5.561936463257537,
#  10.269971871124254,
#  3.403241208493942,
#  4.569632900473312,
#  17.29786575291325,
#  9.435201537430714,
#  12.507155318505163,
#  6.693461638716953,
#  3.4013263135474574,
#  3.418830039408119,
#  14.741866436615627,
#  3.383469974977779,
#  14.848771723116753,
#  10.303374783652389,
#  5.771485260658612,
#  6.82272938745206,
#  3.4025318549308445,
#  2.27939246677,
#  6.8050242620004715,
#  5.722353958408706,
#  3.402472944284412,
#  1.1412158912331491,
#  2.279620934404111,
#  14.816039202881408,
#  1.1595540510263482,
#  2.319316771465532,
#  3.3832731191976633,
#  8.924579283307336,
#  14.502102649909947,
#  5.723895612206888,
#  14.814034791537905,
#  1.1397169858878133,
#  4.5363991567183755,
#  2.318967883094775,
#  3.4020315490567303,
#  6.86692356147133,
#  1.572533729286321,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID	                          45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          45593 non-null  float64
#  3   Delivery_person_Ratings      45593 non-null  float64
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  45593 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weather conditions           45593 non-null  int32
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID	                          45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          45593 non-null  float64
#  3   Delivery_person_Ratings      45593 non-null  float64
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  45593 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weather conditions           45593 non-null  int32
# ...

# %%
train['distances_km']=distances_km

# %%
test['distances_km']=distances_km1

train['Time_Orderd'] = train['Time_Orderd'].values.astype(datetime)

test['Time_Orderd'] = test['Time_Orderd'].values.astype(datetime)

train['Time_Order_picked'] = train['Time_Order_picked'].values.astype(datetime)
test['Time_Order_picked'] = test['Time_Order_picked'].values.astype(datetime)

# %%
train['Time_Orderd'] = train['Time_Orderd'].values.astype(float)

test['Time_Orderd'] = test['Time_Orderd'].values.astype(float)

train['Time_Order_picked'] = train['Time_Order_picked'].values.astype(float)
test['Time_Order_picked'] = test['Time_Order_picked'].values.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-df1089509426> in <module>
# ----> 1 train['Time_Orderd'] = train['Time_Orderd'].values.astype(float)
#       2
#       3 test['Time_Orderd'] = test['Time_Orderd'].values.astype(float)
#       4
#       5 train['Time_Order_picked'] = train['Time_Order_picked'].values.astype(float)
#
# ValueError: could not convert string to float: '11:30'

# %%
X=train[['Delivery_person_Age','Delivery_person_Ratings','distances_km','Weather conditions','Road_traffic_density','Vehicle_condition','Type_of_order','Type_of_vehicle','multiple_deliveries','Festival','City','Age']]

# %%
y=train[['Time_taken (min)']]

# %%
X
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  distances_km  \
# 0                     37.0                      4.9      2.288918
# 1                     34.0                      4.5     14.777225
# 2                     23.0                      4.4      1.136966
# 3                     38.0                      4.7      5.698649
# 4                     32.0                      4.6      4.510871
# ...                    ...                      ...           ...
# 45588                 30.0                      4.8      1.144920
# 45589                 21.0                      4.6     11.007735
# 45590                 30.0                      4.9      3.383273
# 45591                 20.0                      4.7      4.558840
# 45592                 23.0                      4.9      8.924579
#
#        Weather conditions  Road_traffic_density  Vehicle_condition  \
# 0                       4                     0                  2
# ...

# %%
test_x=test[['Delivery_person_Age','Delivery_person_Ratings','distances_km','Weather conditions','Road_traffic_density','Vehicle_condition','Type_of_order','Type_of_vehicle','multiple_deliveries','Festival','City','Age']]

# %%
test["Time_taken (min)"]=0

# %%
test_y=test[['Time_taken (min)']]

# %%
train['Time_Orderd'] = pd.to_datetime(df['Time_Orderd'], format='%H:%M')
train['Time_Order_picked'] = pd.to_datetime(df['Time_Order_picked'], format='%H:%M')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509         try:
# --> 510             values, tz = conversion.datetime_to_datetime64(arg)
#     511             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-9bb0ba75ab9a> in <module>
# ----> 1 train['Time_Orderd'] = pd.to_datetime(df['Time_Orderd'], format='%H:%M')
# ...

# %%
train['Time_taken_to_pick']=train['Time_Orderd']-train['Time_Order_picked']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...

# %%
train['Time_Orderd'].dtypes
# Out:
# dtype('O')

# %%
from sklearn import linear_model

reg=linear_model.LinearRegression()

reg.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(test_x)

# %%
from sklearn.ensemble import RandomForestRegressor
 
 # create regressor object
regressor = RandomForestRegressor(n_estimators = 50,max_depth=10,n_jobs=5,random_state = 0)

# %%
regressor.fit(X,y)
# Out:
# <ipython-input-137-1e6895c5868a>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(X,y)
# RandomForestRegressor(max_depth=10, n_estimators=50, n_jobs=5, random_state=0)

# %%
Y_pred = regressor.predict(test_x)

# %%
z=df1['ID\t']

# %%
z.size
# Out:
# 11399

# %%
from sklearn.metrics import r2_score

# %%
r2_score(test_y, Y_pred)
# Out:
# 0.0

# %%
Y_pred.size
# Out:
# 11399

# %%
df2 = pd.DataFrame({
    "ID":z,
    "Time_taken (min)": Y_pred
})

df2.to_csv("submission1.csv", index=False)

# %%
y_pred
# Out:
# array([[22.19258303],
#        [30.43091189],
#        [29.23309655],
#        ...,
#        [21.25949601],
#        [25.40233469],
#        [17.40626558]])

# %%
df2 = pd.DataFrame({
    "ID":z,
    "Time_taken (min)": Y_pred
})

df2.to_csv("amazon_hackerearth_submission.csv", index=False)
